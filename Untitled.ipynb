# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
y = [0, 0, 0, 3, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4]
yi = range(len(y))

z = [0, 0, 1, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4]
zi = range(len(z))

d = [0, 0, 0, 3, 2, 1, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4]
di = range(len(d))

e = [0, 0, 0, 3, 4, 4, 4, 4, 4, 4, 4, 3, 1, 0, 2, 3]
ei = range(len(e))

u = [0, 0, 0, 3, 4, 4, 4, 4, 4, 4, 4, 4, 3, 1, 0, 2]
ui = range(len(u))

plt.figure(figsize=(15,5))
plt.rc('font',size=18)
plt.plot(yi,y,'*-',label="Teste 1")
plt.plot(zi,z,'*-',label="Teste 2")
plt.plot(di,d,'*-',label="Teste 3")
plt.plot(ei,e,'*-',label="Teste 4")
plt.plot(ui,u,'*-',label="Teste 5")
plt.title("Qualidades do Vídeo com Rede Wi-fi")
plt.xlabel("Chamadas do evento ProgressEvent")
plt.ylabel("Qualidades")
plt.yticks([0,1,2,3,4])
plt.rc('font',size=16)
plt.legend()
plt.savefig('qualidade_wifi.png', format='png')
plt.show()

# %%
y1 =  [0, 0, 1, 1, 0.7848692990543312, 0.6178915500000001, 0.5357175223215633, 0.4645240357142857, 0.40019795000618597, 0.36960627777777777, 0.3276311831907796, 0.33135917499999995, 0.31759325793983145, 0.33008827499999993, 0.3163126579078165]
yi1 = range(len(y1))

z2 = [0, 0, 1, 1, 0.7554070833333334, 0.7728279233017452, 0.6432242, 0.5422501475937561, 0.4701285, 0.4050916064091126, 0.3642396666666667, 0.33155058328876463, 0.3352899, 0.3215240830381022, 0.3340154249999999, 0.33775938344398465]
zi2 = range(len(z2))

d3 = [0, 0, 1, 1, 0.7312185000000001, 0.7109058569316161, 0.62869745, 0.5155723548155148, 0.4722615, 0.41789873180933534, 0.3756215833333333, 0.3243044581076115, 0.3280343, 0.33177948329448714, 0.335500925, 0.3217529080438228]
di3 = range(len(d3))

e4 = [0, 0, 1, 1, 0.7931199245699952, 0.6419868, 0.5412223975509333, 0.46924735714285715, 0.4152822004775688, 0.3635590555555555, 0.3309566582739165, 0.334685375, 0.2302252405773858, 0.3034201075855028, 0.307166275, 0.3196597329914933]
ei4 = range(len(e4))

u5 = [0, 0, 1, 1, 0.7851841740740109, 0.6181255, 0.5505081896045079, 0.4772054642857143, 0.41129532535297886, 0.3600218333333333, 0.3277618581940465, 0.332037075, 0.33837948345948704, 0.21947389943457196, 0.273841075, 0.312808882820222]
ui5 = range(len(u5))

plt.figure(figsize=(15,5))
plt.rc('font',size=18)
plt.plot(yi1,y1,'*-',label="Teste 1")
plt.plot(zi2,z2,'*-',label="Teste 2")
plt.plot(di3,d3,'*-',label="Teste 3")
plt.plot(ei4,e4,'*-',label="Teste 4")
plt.plot(ui5,u5,'*-',label="Teste 5")
plt.title("Taxa de consumo dos buffers com Rede Wi-fi")
plt.xlabel("Chamadas do evento ProgressEvent")
plt.ylabel("Taxa de Consumo $T_{cb}$")
plt.rc('font',size=16)
plt.legend()
plt.savefig('buffer_wifi.png', format='png')
plt.show()

# %%
# TESTE 1
QUALIDADES = [0, 0, 1, 4, 4, 4, 4, 4, 4, 4, 3, 1, 4, 4, 1, 2]
BANDAS = [450000, 450000, 856807.2077190029, 1015959.1869510193, 1738308.880980027, 3199877.831005815, 4028379.1457814854, 4452782.6161239855, 4788641.814013743, 4979948.012956294, 4540944.073796807, 4489946.523514375, 4489946.523514375, 3990166.0711889733, 2821590.5116506387, 61559.55767238912]
BUFFER = [0, 0, 1, 1, 0.7754119234632453, 0.66285225, 0.5586302316095929, 0.4841685, 0.40646395020199844, 0.3654750277777778, 0.3326788083169702, 0.22791943526562608, 0.31017797500000005, 0.32268500806712525, 0.29143360000000007, 0.29517065737926645]
STALLS = []
# TESTE 2
QUALIDADES = [0, 0, 1, 4, 4, 4, 4, 4, 4, 4, 4, 4]
BUFFER = [0, 0, 1, 1, 0.7726077982879874, 0.5567444815310201, 0.36419888888888896, 0.3315238832880971, 0.30027014999999996, 0.32151033303775833, 0.31650674999999995, 0.3290120082253002]
STALLS = []
# TESTE 3
QUALIDADES = [0, 0, 1, 4, 4, 4, 4, 4, 4, 4, 3, 2, 1, 2, 4]
BUFFER = [0, 0, 1, 1, 0.7992641124540071, 0.6294111499999999, 0.5161550215064592, 0.46029564285714286, 0.3965079811408744, 0.3566186944444445, 0.307210557680264, 0.27595875000000003, 0.17759958261986308, 0.23187921686746982, 0.3222138080553453]
STALLS = []
# TESTE 4
QUALIDADES = [0, 0, 0, 3, 4, 4, 3, 4, 4, 4, 2, 3, 0, 2, 4, 4]
BUFFER = [0, 0, 1, 1, 0.7709981731873857, 0.62428195, 0.4973270623886276, 0.31914607142857143, 0.3714444491076391, 0.36349661111111115, 0.2959004573975115, 0.27339909999999995, 0.17008002002962525, 0.22537848615569828, 0.3159074499999999, 0.3196642579916065]
STALLS = []
# TESTE 5
QUALIDADES = [0, 0, 0, 2, 4, 4, 4, 4, 3, 2, 3, 4, 4, 4]
BUFFER = [0, 0, 1, 1, 0.38518654999999996, 0.4293114345546431, 0.46085410714285713, 0.4079417314981791, 0.36677927777777775, 0.17926855427715785, 0.23417060848707028, 0.3238694330967358, 0.31010942499999994, 0.3313650582841266]
STALLS = []

yg = [0, 0, 1, 4, 4, 4, 4, 4, 4, 4, 3, 1, 4, 4, 1, 2]
ygi = range(len(yg))

zg = [0, 0, 1, 4, 4, 4, 4, 4, 4, 4, 4, 4]
zgi = range(len(zg))

dg = [0, 0, 1, 4, 4, 4, 4, 4, 4, 4, 3, 2, 1, 2, 4]
dgi = range(len(dg))

eg = [0, 0, 0, 3, 4, 4, 3, 4, 4, 4, 2, 3, 0, 2, 4, 4]
egi = range(len(eg))

ug = [0, 0, 0, 2, 4, 4, 4, 4, 3, 2, 3, 4, 4, 4]
ugi = range(len(ug))


yg1 = [0, 0, 1, 1, 0.7754119234632453, 0.66285225, 0.5586302316095929, 0.4841685, 0.40646395020199844, 0.3654750277777778, 0.3326788083169702, 0.22791943526562608, 0.31017797500000005, 0.32268500806712525, 0.29143360000000007, 0.29517065737926645]
ygi1 = range(len(yg1))

zg2 = [0, 0, 1, 1, 0.7726077982879874, 0.5567444815310201, 0.36419888888888896, 0.3315238832880971, 0.30027014999999996, 0.32151033303775833, 0.31650674999999995, 0.3290120082253002]
zgi2 = range(len(zg2))

dg3 = [0, 0, 1, 1, 0.7992641124540071, 0.6294111499999999, 0.5161550215064592, 0.46029564285714286, 0.3965079811408744, 0.3566186944444445, 0.307210557680264, 0.27595875000000003, 0.17759958261986308, 0.23187921686746982, 0.3222138080553453]
dgi3 = range(len(dg3))

eg4 = [0, 0, 1, 1, 0.7709981731873857, 0.62428195, 0.4973270623886276, 0.31914607142857143, 0.3714444491076391, 0.36349661111111115, 0.2959004573975115, 0.27339909999999995, 0.17008002002962525, 0.22537848615569828, 0.3159074499999999, 0.3196642579916065]
egi4 = range(len(eg4))

ug5 = [0, 0, 1, 1, 0.38518654999999996, 0.4293114345546431, 0.46085410714285713, 0.4079417314981791, 0.36677927777777775, 0.17926855427715785, 0.23417060848707028, 0.3238694330967358, 0.31010942499999994, 0.3313650582841266]
ugi5 = range(len(ug5))


plt.figure(figsize=(15,5))
plt.rc('font',size=18)
plt.plot(ygi1,yg1,'*-',label="Teste 1")
plt.plot(zgi2,zg2,'*-',label="Teste 2")
plt.plot(dgi3,dg3,'*-',label="Teste 3")
plt.plot(egi4,eg4,'*-',label="Teste 4")
plt.plot(ugi5,ug5,'*-',label="Teste 5")
plt.title("Taxa de consumo dos buffers com Rede 4G")
plt.xlabel("Chamadas do evento ProgressEvent")
plt.ylabel("Taxa de Consumo $T_{cb}$")
plt.rc('font',size=16)
plt.legend()
plt.savefig('buffer_4g.png', format='png')
plt.show()

# %%
plt.figure(figsize=(15,5))
plt.rc('font',size=18)
plt.plot(ygi,yg,'*-',label="Teste 1")
plt.plot(zgi,zg,'*-',label="Teste 2")
plt.plot(dgi,dg,'*-',label="Teste 3")
plt.plot(egi,eg,'*-',label="Teste 4")
plt.plot(ugi,ug,'*-',label="Teste 5")
plt.title("Qualidades do Vídeo com Rede 4G")
plt.xlabel("Chamadas do evento ProgressEvent")
plt.ylabel("Qualidades")
plt.yticks([0,1,2,3,4])
plt.rc('font',size=16)
plt.legend()
plt.savefig('qualidade_4g.png', format='png')
plt.show()

# %%
# TESTE 4
QUALIDADES = [0, 0, 0, 3, 4, 4, 4, 4, 4, 4, 4, 3, 1, 0, 2, 3]
BANDAS = [1250000, 1250000, 698468.3013408777, 1063782.5728683735, 1723699.787058565, 2489709.4301099945, 4216887.981383999, 4603615.82525058, 4841732.408929118, 5044371.921519962, 5261192.086516513, 4794600.7674333295, 3970719.9145805254, 4112632.3268603287, 2769757.7447921624, 3298083.947861396]
BUFFER = [0, 0, 1, 1, 0.7931199245699952, 0.6419868, 0.5412223975509333, 0.46924735714285715, 0.4152822004775688, 0.3635590555555555, 0.3309566582739165, 0.334685375, 0.2302252405773858, 0.3034201075855028, 0.307166275, 0.3196597329914933]
STALLS = []

# %%
# TESTE 5
QUALIDADES = [0, 0, 0, 3, 4, 4, 4, 4, 4, 4, 4, 4, 3, 1, 0, 2]
BANDAS = [1250000, 1250000, 880264.1523291343, 1149563.8500197746, 1763442.276256723, 2431534.398171965, 4098266.745091831, 4442081.36882321, 3997467.2441992713, 4176590.7370548355, 4865993.336929161, 5125861.337256265, 4722577.04929238, 3204995.011425117, 3359230.236551489, 2422887.6300283363]
BUFFER = [0, 0, 1, 1, 0.7851841740740109, 0.6181255, 0.5505081896045079, 0.4772054642857143, 0.41129532535297886, 0.3600218333333333, 0.3277618581940465, 0.332037075, 0.33837948345948704, 0.21947389943457196, 0.273841075, 0.312808882820222]
STALLS = []
