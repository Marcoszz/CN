# %% [markdown]
# # Preparação e análise de Dados em Python #
#
# Nesta aula, aprenderemos um pouco a como entender melhor um conjunto de dados. Nos tempos atuais, é cada vez mais fácil conseguir quantidades cada vez maiores de dados. Contudo, isto vem com um custo: quanto mais dados, mais difícil é de __entender__ os mesmos.
#
# Hoje, aprenderemos a utilizar a biblioteca Pandas para manipular dados.

# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline
#!pip3 install pandas --user

# %% [markdown]
# Na aula de hoje, usaremos uma base de dados sobre número de vendas de jogos de videogame até 2016. Nosso objetivo é entender melhor os dados para na sequência produzir modelos de regressão que melhor prevejam os números de vendas. Baixe o arquivo que está no Colabweb e coloque-o descomprimido na mesma pasta em que está rodando este notebook:

# %%
vg = pd.read_csv('Video_Games_Sales_as_at_22_Dec_2016.csv')

# %% [markdown]
# O Pandas é uma biblioteca de manipulação de dados. A função read_csv lê __todo__ conteúdo do arquivo e coloca em uma estrutura de dados. Existem funções similares para diversos tipos de arquivos, como `xls` e `json`.
#
# Agora vamos visualizar o conteúdo dos nossos dados. Para isto, usaremos a função head, que mostra os 5 primeiros registros:

# %%
vg.head()
#vg.tail()
#vg.sample(5)
# Out:
#                        Name Platform  Year_of_Release         Genre Publisher  \
# 0                Wii Sports      Wii           2006.0        Sports  Nintendo
# 1         Super Mario Bros.      NES           1985.0      Platform  Nintendo
# 2            Mario Kart Wii      Wii           2008.0        Racing  Nintendo
# 3         Wii Sports Resort      Wii           2009.0        Sports  Nintendo
# 4  Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  Critic_Score  \
# 0     41.36     28.96      3.77         8.45         82.53          76.0
# 1     29.08      3.58      6.81         0.77         40.24           NaN
# 2     15.68     12.76      3.79         3.29         35.52          82.0
# 3     15.61     10.93      3.28         2.95         32.77          80.0
# 4     11.27      8.89     10.22         1.00         31.37           NaN
#
#    Critic_Count  User_Score  User_Count Developer Rating
# 0          51.0         8.0       322.0  Nintendo      E
# 1           NaN         NaN         NaN       NaN    NaN
# 2          73.0         8.3       709.0  Nintendo      E
# 3          73.0         8.0       192.0  Nintendo      E
# 4           NaN         NaN         NaN       NaN    NaN

# %%
vg.columns
# Out:
# Index(['Name', 'Platform', 'Year_of_Release', 'Genre', 'Publisher', 'NA_Sales',
#        'EU_Sales', 'JP_Sales', 'Other_Sales', 'Global_Sales', 'Critic_Score',
#        'Critic_Count', 'User_Score', 'User_Count', 'Developer', 'Rating'],
#       dtype='object')

# %%
vg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16719 entries, 0 to 16718
# Data columns (total 16 columns):
# Name               16717 non-null object
# Platform           16719 non-null object
# Year_of_Release    16450 non-null float64
# Genre              16717 non-null object
# Publisher          16665 non-null object
# NA_Sales           16719 non-null float64
# EU_Sales           16719 non-null float64
# JP_Sales           16719 non-null float64
# Other_Sales        16719 non-null float64
# Global_Sales       16719 non-null float64
# Critic_Score       8137 non-null float64
# Critic_Count       8137 non-null float64
# User_Score         7590 non-null float64
# User_Count         7590 non-null float64
# Developer          10096 non-null object
# Rating             9950 non-null object
# dtypes: float64(10), object(6)
# memory usage: 2.0+ MB

# %% [markdown]
# Acessando os dados de um jogo especifico:

# %%
vg.loc[130]
#vg.loc[[1,5,10,20]]
# Out:
# Name               The Elder Scrolls V: Skyrim
# Platform                                   PS3
# Year_of_Release                           2011
# Genre                             Role-Playing
# Publisher                   Bethesda Softworks
# NA_Sales                                  2.55
# EU_Sales                                   2.6
# JP_Sales                                  0.25
# Other_Sales                                  1
# Global_Sales                              6.41
# Critic_Score                                92
# Critic_Count                                16
# User_Score                                 6.4
# User_Count                                2527
# Developer                Bethesda Game Studios
# Rating                                       M
# Name: 130, dtype: object

# %% [markdown]
# Podemos também acessar colunas especificas através dos seus nomes:

# %%
vg[['Name','Critic_Score']]
#vg.Global_Sales
# Out:
#                                                     Name  Critic_Score
# 0                                             Wii Sports          76.0
# 1                                      Super Mario Bros.           NaN
# 2                                         Mario Kart Wii          82.0
# 3                                      Wii Sports Resort          80.0
# 4                               Pokemon Red/Pokemon Blue           NaN
# 5                                                 Tetris           NaN
# 6                                  New Super Mario Bros.          89.0
# 7                                               Wii Play          58.0
# 8                              New Super Mario Bros. Wii          87.0
# 9                                              Duck Hunt           NaN
# 10                                            Nintendogs           NaN
# 11                                         Mario Kart DS          91.0
# 12                           Pokemon Gold/Pokemon Silver           NaN
# 13                                               Wii Fit          80.0
# 14                                    Kinect Adventures!          61.0
# 15                                          Wii Fit Plus          80.0
# 16                                    Grand Theft Auto V          97.0
# 17                         Grand Theft Auto: San Andreas          95.0
# 18                                     Super Mario World           NaN
# 19          Brain Age: Train Your Brain in Minutes a Day          77.0
# 20                         Pokemon Diamond/Pokemon Pearl           NaN
# 21                                      Super Mario Land           NaN
# 22                                   Super Mario Bros. 3           NaN
# 23                                    Grand Theft Auto V          97.0
# 24                           Grand Theft Auto: Vice City          95.0
# 25                         Pokemon Ruby/Pokemon Sapphire           NaN
# 26           Brain Age 2: More Training in Minutes a Day          77.0
# 27                           Pokemon Black/Pokemon White           NaN
# 28                                Gran Turismo 3: A-Spec          95.0
# 29                        Call of Duty: Modern Warfare 3          88.0
# ...                                                  ...           ...
# 16689              Help Wanted: 50 Wacky Jobs (jp sales)           NaN
# 16690  Yattaman Wii: BikkuriDokkiri Machine de Mou Ra...           NaN
# 16691                              Neo Angelique Special           NaN
# 16692                      Outdoors Unleashed: Africa 3D           NaN
# 16693                                          Real Rode           NaN
# 16694                                     Pony Friends 2           NaN
# 16695                       Dynasty Warriors: Eiketsuden           NaN
# 16696                  Metal Gear Solid V: Ground Zeroes          80.0
# 16697                                  PGA European Tour           NaN
# 16698                                     Carmageddon 64           NaN
# 16699                                    Planet Monsters          67.0
# 16700                                             Breach          61.0
# 16701                                   Bust-A-Move 3000          53.0
# 16702                                   Mega Brain Boost          48.0
# 16703                              The Longest 5 Minutes           NaN
# 16704                           Mezase!! Tsuri Master DS           NaN
# 16705  Eiyuu Densetsu: Sora no Kiseki Material Collec...           NaN
# 16706                            STORM: Frontline Nation          60.0
# 16707                                   Strawberry Nauts           NaN
# 16708                                           Plushees           NaN
# 16709                                            15 Days          63.0
# 16710                      Men in Black II: Alien Escape           NaN
# 16711                                   Aiyoku no Eustia           NaN
# 16712                 Woody Woodpecker in Crazy Castle 5           NaN
# 16713   SCORE International Baja 1000: The Official Game           NaN
# 16714                      Samurai Warriors: Sanada Maru           NaN
# 16715                                   LMA Manager 2007           NaN
# 16716                            Haitaka no Psychedelica           NaN
# 16717                                   Spirits & Spells           NaN
# 16718                                Winning Post 8 2016           NaN
#
# [16719 rows x 2 columns]

# %% [markdown]
# Quantos jogos para cada sistema nós temos?

# %%
vg.Developer.value_counts()
# Out:
# Ubisoft                                                                             204
# EA Sports                                                                           172
# EA Canada                                                                           167
# Konami                                                                              162
# Capcom                                                                              139
# EA Tiburon                                                                          108
# Electronic Arts                                                                     104
# Ubisoft Montreal                                                                    101
# Visual Concepts                                                                      99
# Omega Force                                                                          80
# Traveller's Tales                                                                    77
# Vicarious Visions                                                                    76
# Activision                                                                           75
# TT Games                                                                             73
# Nintendo                                                                             72
# THQ                                                                                  71
# Namco                                                                                64
# Codemasters                                                                          62
# Artificial Mind and Movement                                                         61
# Midway                                                                               60
# Yuke's                                                                               59
# Harmonix Music Systems                                                               56
# High Voltage Software                                                                55
# Maxis                                                                                49
# Square Enix                                                                          48
# Eurocom Entertainment Software                                                       47
# FUN Labs                                                                             46
# Arc System Works                                                                     46
# Neversoft Entertainment                                                              46
# Treyarch                                                                             44
#                                                                                    ...
# Rainbow S.p.A.                                                                        1
# BIP Games                                                                             1
# Office Create                                                                         1
# Volition Inc., CD Projekt Red Studio, CD Projekt, CD Projekt Localisation Centre      1
# Jupiter Corporation, Jupiter Multimedia                                               1
# Triple Eh? Ltd                                                                        1
# Treyarch, Infinity Ward                                                               1
# Wildfire Studios                                                                      1
# Punchline, Shirogumi                                                                  1
# Nintendo, Namco Bandai Games                                                          1
# Foundation 9 Entertainment                                                            1
# Hudson, NATSUME ATARI Inc.                                                            1
# Phosphor Games Studio, LLC                                                            1
# Mindware Studios                                                                      1
# Anchor Bay Entertainment                                                              1
# K2, Kurogane                                                                          1
# ThatGameCompany                                                                       1
# HexaDrive                                                                             1
# Zener Works                                                                           1
# Pacific Century Cyber Works                                                           1
# Lead Pursuit                                                                          1
# Cohort Studios                                                                        1
# SilverBirch Studios                                                                   1
# Kronos Digital Entertainment                                                          1
# Big Head Games Ltd.                                                                   1
# Eurocom Entertainment Software, Visceral Games                                        1
# IR Gurus Interactive Ltd.                                                             1
# Mahou                                                                                 1
# Hello Games                                                                           1
# THQ, Yuke's                                                                           1
# Name: Developer, Length: 1696, dtype: int64

# %% [markdown]
# Contando a quantidade de valores diferentes de um atributo numérico:

# %%
vg.Critic_Score.value_counts()
# Out:
# 70.0    256
# 71.0    254
# 75.0    245
# 78.0    240
# 73.0    238
# 80.0    237
# 76.0    235
# 72.0    226
# 74.0    226
# 77.0    225
# 68.0    219
# 81.0    218
# 79.0    218
# 69.0    215
# 82.0    208
# 83.0    206
# 66.0    203
# 65.0    192
# 84.0    183
# 67.0    182
# 63.0    178
# 62.0    170
# 64.0    169
# 61.0    165
# 59.0    157
# 60.0    156
# 85.0    151
# 58.0    151
# 86.0    137
# 57.0    132
#        ...
# 94.0     37
# 42.0     37
# 38.0     34
# 41.0     29
# 37.0     28
# 35.0     27
# 36.0     26
# 40.0     26
# 33.0     22
# 96.0     18
# 95.0     16
# 32.0     15
# 26.0     12
# 30.0     12
# 28.0     11
# 97.0     11
# 34.0     10
# 31.0      9
# 27.0      8
# 25.0      7
# 19.0      6
# 23.0      4
# 24.0      4
# 98.0      4
# 29.0      3
# 20.0      3
# 17.0      1
# 22.0      1
# 13.0      1
# 21.0      1
# Name: Critic_Score, Length: 82, dtype: int64

# %% [markdown]
# Muito né? melhor seria colocar em categorias:

# %%
b = list(range(0,110,5))
vg.Critic_Score.value_counts(bins=b)
# Out:
# (70.0, 75.0]      1189
# (75.0, 80.0]      1155
# (65.0, 70.0]      1075
# (80.0, 85.0]       966
# (60.0, 65.0]       874
# (55.0, 60.0]       709
# (85.0, 90.0]       552
# (50.0, 55.0]       479
# (45.0, 50.0]       354
# (90.0, 95.0]       224
# (40.0, 45.0]       217
# (35.0, 40.0]       153
# (30.0, 35.0]        83
# (25.0, 30.0]        46
# (95.0, 100.0]       33
# (20.0, 25.0]        17
# (15.0, 20.0]        10
# (10.0, 15.0]         1
# (5.0, 10.0]          0
# (100.0, 105.0]       0
# (-0.001, 5.0]        0
# Name: Critic_Score, dtype: int64

# %% [markdown]
# O Pandas oferece vários métodos para entender melhor os dados com estatísticas básicas:

# %%
vg.describe()
# Out:
#        Year_of_Release      NA_Sales      EU_Sales      JP_Sales  \
# count     16450.000000  16719.000000  16719.000000  16719.000000
# mean       2006.487356      0.263330      0.145025      0.077602
# std           5.878995      0.813514      0.503283      0.308818
# min        1980.000000      0.000000      0.000000      0.000000
# 25%        2003.000000      0.000000      0.000000      0.000000
# 50%        2007.000000      0.080000      0.020000      0.000000
# 75%        2010.000000      0.240000      0.110000      0.040000
# max        2020.000000     41.360000     28.960000     10.220000
#
#         Other_Sales  Global_Sales  Critic_Score  Critic_Count   User_Score  \
# count  16719.000000  16719.000000   8137.000000   8137.000000  7590.000000
# mean       0.047332      0.533543     68.967679     26.360821     7.125046
# std        0.186710      1.547935     13.938165     18.980495     1.500006
# min        0.000000      0.010000     13.000000      3.000000     0.000000
# 25%        0.000000      0.060000     60.000000     12.000000     6.400000
# 50%        0.010000      0.170000     71.000000     21.000000     7.500000
# 75%        0.030000      0.470000     79.000000     36.000000     8.200000
# max       10.570000     82.530000     98.000000    113.000000     9.700000
#
#          User_Count
# count   7590.000000
# mean     162.229908
# std      561.282326
# min        4.000000
# 25%       10.000000
# 50%       24.000000
# 75%       81.000000
# max    10665.000000

# %% [markdown]
# Epa! Tem um jogo com lançamento em 2020! Não pode, pois a base é de jogos lançados até 2016. Na verdade, isso é super comum com dados reais, de haver sujeira na base de dados.
#
# E agora, como podemos identificar que jogo é esse ?

# %%
vg[vg['Year_of_Release']==2020]
#vg[(vg.Year_of_Release<2017)&(vg.Platform=='SNES')].head()
# Out:
#                         Name Platform  Year_of_Release       Genre Publisher  \
# 5936  Imagine: Makeup Artist       DS           2020.0  Simulation   Ubisoft
#
#       NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  Critic_Score  \
# 5936      0.27       0.0       0.0         0.02          0.29           NaN
#
#       Critic_Count  User_Score  User_Count Developer Rating
# 5936           NaN         NaN         NaN   Ubisoft      E

# %% [markdown]
# Conseguiu entender como funcionou? Brinque um pouco com os dados para entender melhor.
#
# Quais são os jogos mais recentes da base para Nintendo Wii?

# %%
vg[vg.Platform=='Wii'].sort_values(['JP_Sales'],ascending = False).head()
# Out:
#                          Name Platform  Year_of_Release     Genre Publisher  \
# 8   New Super Mario Bros. Wii      Wii           2009.0  Platform  Nintendo
# 2              Mario Kart Wii      Wii           2008.0    Racing  Nintendo
# 0                  Wii Sports      Wii           2006.0    Sports  Nintendo
# 13                    Wii Fit      Wii           2007.0    Sports  Nintendo
# 3           Wii Sports Resort      Wii           2009.0    Sports  Nintendo
#
#     NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  Critic_Score  \
# 8      14.44      6.94      4.70         2.24         28.32          87.0
# 2      15.68     12.76      3.79         3.29         35.52          82.0
# 0      41.36     28.96      3.77         8.45         82.53          76.0
# 13      8.92      8.03      3.60         2.15         22.70          80.0
# 3      15.61     10.93      3.28         2.95         32.77          80.0
#
#     Critic_Count  User_Score  User_Count Developer Rating
# 8           80.0         8.4       594.0  Nintendo      E
# 2           73.0         8.3       709.0  Nintendo      E
# 0           51.0         8.0       322.0  Nintendo      E
# 13          63.0         7.7       146.0  Nintendo      E
# 3           73.0         8.0       192.0  Nintendo      E

# %% [markdown]
# A saída de boa parte de comandos em Pandas gera objetos do tipo dataframe ou series. Estes objetos novos podem ser utilizados com outras funções pandas, em cascata.
#
# Isto são condições compostas
#
# Jogos de PS3 que tiveram mais do que 20 críticas ordenados pela nota da critica:

# %%
vg[(vg.Platform=='PS2') & (vg.Critic_Count>20)].sort_values(['Critic_Score']).head()
# Out:
#                                      Name Platform  Year_of_Release  \
# 12012           McFarlane's Evil Prophecy      PS2              NaN
# 5337    Charlie and the Chocolate Factory      PS2           2005.0
# 7982                           Fight Club      PS2           2004.0
# 1230           The Simpsons Skateboarding      PS2           2002.0
# 3449   Terminator 3: Rise of the Machines      PS2           2003.0
#
#            Genre                     Publisher  NA_Sales  EU_Sales  JP_Sales  \
# 12012     Action  Konami Digital Entertainment      0.03      0.03       0.0
# 5337   Adventure                   Global Star      0.17      0.13       0.0
# 7982    Fighting                 Vivendi Games      0.09      0.07       0.0
# 1230      Sports               Electronic Arts      0.36      0.90       0.0
# 3449      Action                         Atari      0.28      0.22       0.0
#
#        Other_Sales  Global_Sales  Critic_Score  Critic_Count  User_Score  \
# 12012         0.01          0.07          34.0          28.0         3.2
# 5337          0.04          0.35          35.0          21.0         4.1
# 7982          0.02          0.18          36.0          28.0         4.4
# 1230          0.27          1.52          38.0          21.0         5.0
# 3449          0.07          0.58          38.0          21.0         6.3
#
#        User_Count                                      Developer Rating
# 12012         5.0                                         Konami      M
# 5337         28.0  High Voltage Software, Backbone Entertainment      E
# 7982         22.0                                  Genuine Games      M
# 1230         26.0                               The Code Monkeys      T
# 3449         23.0                        Black Ops Entertainment      T

# %% [markdown]
# Exercício:
#
#
# 1 - Gere uma base vg2, contendo todos os jogos lançados de 2000 a 2016 e a descreva com describe
#
# 2 - Mostre todos os jogos lançados até o ano 2000 onde as vendas japonesas foram acima das americanas, ordenado por vendas globais
#
# 3 - Conte, para cada plataforma, quantos jogos com nota de usuário acima de 8 cada uma tem

# %%
vg2=vg[(vg.Year_of_Release>=2000) & (vg.Year_of_Release<=2016)] 
vg2.describe()
# Out:
#        Year_of_Release      NA_Sales      EU_Sales      JP_Sales  \
# count     14470.000000  14470.000000  14470.000000  14470.000000
# mean       2008.022322      0.243926      0.144133      0.056380
# std           4.111160      0.713256      0.513172      0.249723
# min        2000.000000      0.000000      0.000000      0.000000
# 25%        2005.000000      0.000000      0.000000      0.000000
# 50%        2008.000000      0.080000      0.020000      0.000000
# 75%        2011.000000      0.230000      0.110000      0.030000
# max        2016.000000     41.360000     28.960000      6.500000
#
#         Other_Sales  Global_Sales  Critic_Score  Critic_Count   User_Score  \
# count  14470.000000  14470.000000   7887.000000   7887.000000  7371.000000
# mean       0.050319      0.495031     68.858882     26.601750     7.110975
# std        0.198335      1.463424     13.869432     19.041747     1.498326
# min        0.000000      0.010000     13.000000      3.000000     0.000000
# 25%        0.000000      0.060000     60.000000     12.000000     6.400000
# 50%        0.010000      0.160000     71.000000     22.000000     7.500000
# 75%        0.040000      0.440000     79.000000     37.000000     8.200000
# max       10.570000     82.530000     98.000000    113.000000     9.700000
#
#          User_Count
# count   7371.000000
# mean     161.464523
# std      561.626621
# min        4.000000
# 25%       10.000000
# 50%       24.000000
# 75%       81.000000
# max    10665.000000

# %% [markdown]
# ### Usando pandas para plotar com pyplot ###
#
# Uma coisa legal no pandas é que ele é integrado ao pyplot/matplotlib.
#
# Exemplo: Qual a relação entre as vendas globais e a nota da crítica?

# %%
vg.plot(kind='scatter',x='Critic_Score',y='NA_Sales')

# %% [markdown]
# Os valores muito altos (como o Wii Sports com 80 milhões de cópias), estão dificultando a visualização. Para resolver este problema, podemos ou eliminar estes valores do plot ou plotar em escala logaritmica:

# %%
vg[vg.NA_Sales<20].plot(kind='scatter',x='Critic_Score',y='NA_Sales')

vg.plot(kind='scatter',x='Critic_Score',y='Global_Sales',logy=True)

# %% [markdown]
# ### Outras correlações mais sofisticadas ###
#
# Como será a comparação entre as notas dos críticos para RPGs em comparação com jogos de corrida?

# %%
# Primeiro veremos o histograma global
vg.Critic_Score.hist(bins = 20)

# %%
#Agora apenas dos RPGs
vg[vg.Genre=='Role-Playing'].Critic_Score.hist(bins = 20)

# %%
# Podemos comparar os RPGs com os jogos de corrida

bins = list(range(0,100,5))
vgval = vg[vg.Critic_Score.notnull()] # Remover os jogos sem valor de Critic_Score

plt.hist(vgval[vgval.Genre=='Role-Playing'].Critic_Score,bins,alpha=0.5,label='RPG')
plt.hist(vgval[vgval.Genre=='Racing'].Critic_Score,bins,alpha=0.5,label='Corrida')
plt.legend()

# %% [markdown]
# E se eu quiser comparar variáveis categóricas?
#
# Vamos analisar duas: Gênero e Plataforma.

# %%
pd.crosstab(vg.Platform,vg.Genre,margins = True)
# Out:
# Genre     Action  Adventure  Fighting  Misc  Platform  Puzzle  Racing  \
# Platform
# 2600          61          2         2     5         9      11       6
# 3DO            0          1         0     0         0       1       0
# 3DS          188         38        14    54        28      20      11
# DC             3         11        12     0         2       0       6
# DS           340        238        36   391        91     236      67
# GB             6          5         0     8        19      15       2
# GBA          167         38        23   110       142      41      64
# GC           101         20        42    36        73      13      63
# GEN            3          2         5     1         7       0       1
# GG             0          0         0     0         1       0       0
# N64           38          4        29    18        30      12      57
# NES           13          1         4     2        28      14       4
# NG             0          0        11     0         0       0       0
# PC           170         65         6    24        11      25      61
# PCFX           0          0         0     0         0       0       0
# PS           157         69       108    76        64      32     145
# PS2          348        196       150   222       103      18     216
# PS3          380         74        76   125        37       3      92
# PS4          144         28        18    20        12       1      19
# PSP          222        213        74   106        36      44      63
# PSV          150         93        16    24         9       3      11
# SAT            3         26        31    15         5       5       8
# SCD            0          0         0     2         1       0       1
# SNES          12          4        25    17        26      13       9
# TG16           0          1         0     0         0       0       0
# WS             0          0         0     0         0       0       0
# Wii          237         83        42   280        58      55      93
# WiiU          64          3         5    22        17       4       3
# X360         323         48        65   127        25       7     104
# XB           155         26        48    46        49       7     123
# XOne          85         14         7    19         5       0      20
# All         3370       1303       849  1750       888     580    1249
#
# Genre     Role-Playing  Shooter  Simulation  Sports  Strategy    All
# Platform
# 2600                 0       24           1      12         0    133
# 3DO                  0        0           1       0         0      3
# 3DS                 88        7          31      26        15    520
# DC                   4        3           1      10         0     52
# DS                 200       42         284     148        79   2152
# GB                  21        1           5       9         7     98
# GBA                 73       40          18      88        18    822
# GC                  27       48          12     110        11    556
# GEN                  3        1           0       3         1     27
# GG                   0        0           0       0         0      1
# N64                  8       24          10      80         9    319
# NES                 11        7           0      14         0     98
# NG                   0        0           0       1         0     12
# PC                 104      150         120      50       188    974
# PCFX                 1        0           0       0         0      1
# PS                  97       96          60     222        71   1197
# PS2                187      160          90     400        71   2161
# PS3                119      156          31     214        24   1331
# PS4                 52       41           6      46         6    393
# PSP                192       37          28     134        60   1209
# PSV                 87        5           4      23         7    432
# SAT                 17       22           7      16        18    173
# SCD                  1        0           0       0         1      6
# SNES                50       10           9      49        15    239
# TG16                 0        1           0       0         0      2
# WS                   4        0           0       0         2      6
# Wii                 35       65          87     260        25   1320
# WiiU                 7       10           1       8         3    147
# X360                75      203          40     217        28   1262
# XB                  23      132          24     170        21    824
# XOne                14       38           4      38         3    247
# All               1500     1323         874    2348       683  16717

# %% [markdown]
# E se a gente quisesse esses valores em porcentagens? Podemos então aplicar uma __função lambda__ nos dados:

# %%
pd.crosstab(vg.Platform,vg.Genre,margins = True).apply(lambda v:100*v/v[-1],axis = 1)
# Out:
# Genre        Action  Adventure   Fighting       Misc    Platform     Puzzle  \
# Platform
# 2600      45.864662   1.503759   1.503759   3.759398    6.766917   8.270677
# 3DO        0.000000  33.333333   0.000000   0.000000    0.000000  33.333333
# 3DS       36.153846   7.307692   2.692308  10.384615    5.384615   3.846154
# DC         5.769231  21.153846  23.076923   0.000000    3.846154   0.000000
# DS        15.799257  11.059480   1.672862  18.169145    4.228625  10.966543
# GB         6.122449   5.102041   0.000000   8.163265   19.387755  15.306122
# GBA       20.316302   4.622871   2.798054  13.381995   17.274939   4.987835
# GC        18.165468   3.597122   7.553957   6.474820   13.129496   2.338129
# GEN       11.111111   7.407407  18.518519   3.703704   25.925926   0.000000
# GG         0.000000   0.000000   0.000000   0.000000  100.000000   0.000000
# N64       11.912226   1.253918   9.090909   5.642633    9.404389   3.761755
# NES       13.265306   1.020408   4.081633   2.040816   28.571429  14.285714
# NG         0.000000   0.000000  91.666667   0.000000    0.000000   0.000000
# PC        17.453799   6.673511   0.616016   2.464066    1.129363   2.566735
# PCFX       0.000000   0.000000   0.000000   0.000000    0.000000   0.000000
# PS        13.116124   5.764411   9.022556   6.349206    5.346700   2.673350
# PS2       16.103656   9.069875   6.941231  10.273022    4.766312   0.832948
# PS3       28.549962   5.559730   5.709992   9.391435    2.779865   0.225394
# PS4       36.641221   7.124682   4.580153   5.089059    3.053435   0.254453
# PSP       18.362283  17.617866   6.120761   8.767577    2.977667   3.639371
# PSV       34.722222  21.527778   3.703704   5.555556    2.083333   0.694444
# SAT        1.734104  15.028902  17.919075   8.670520    2.890173   2.890173
# SCD        0.000000   0.000000   0.000000  33.333333   16.666667   0.000000
# SNES       5.020921   1.673640  10.460251   7.112971   10.878661   5.439331
# TG16       0.000000  50.000000   0.000000   0.000000    0.000000   0.000000
# WS         0.000000   0.000000   0.000000   0.000000    0.000000   0.000000
# Wii       17.954545   6.287879   3.181818  21.212121    4.393939   4.166667
# WiiU      43.537415   2.040816   3.401361  14.965986   11.564626   2.721088
# X360      25.594295   3.803487   5.150555  10.063391    1.980983   0.554675
# XB        18.810680   3.155340   5.825243   5.582524    5.946602   0.849515
# XOne      34.412955   5.668016   2.834008   7.692308    2.024291   0.000000
# All       20.159119   7.794461   5.078662  10.468385    5.311958   3.469522
#
# Genre        Racing  Role-Playing    Shooter  Simulation     Sports  \
# Platform
# 2600       4.511278      0.000000  18.045113    0.751880   9.022556
# 3DO        0.000000      0.000000   0.000000   33.333333   0.000000
# 3DS        2.115385     16.923077   1.346154    5.961538   5.000000
# DC        11.538462      7.692308   5.769231    1.923077  19.230769
# DS         3.113383      9.293680   1.951673   13.197026   6.877323
# GB         2.040816     21.428571   1.020408    5.102041   9.183673
# GBA        7.785888      8.880779   4.866180    2.189781  10.705596
# GC        11.330935      4.856115   8.633094    2.158273  19.784173
# GEN        3.703704     11.111111   3.703704    0.000000  11.111111
# GG         0.000000      0.000000   0.000000    0.000000   0.000000
# N64       17.868339      2.507837   7.523511    3.134796  25.078370
# NES        4.081633     11.224490   7.142857    0.000000  14.285714
# NG         0.000000      0.000000   0.000000    0.000000   8.333333
# PC         6.262834     10.677618  15.400411   12.320329   5.133470
# PCFX       0.000000    100.000000   0.000000    0.000000   0.000000
# PS        12.113617      8.103592   8.020050    5.012531  18.546366
# PS2        9.995373      8.653401   7.403980    4.164739  18.509949
# PS3        6.912096      8.940646  11.720511    2.329076  16.078137
# PS4        4.834606     13.231552  10.432570    1.526718  11.704835
# PSP        5.210918     15.880893   3.060380    2.315964  11.083540
# PSV        2.546296     20.138889   1.157407    0.925926   5.324074
# SAT        4.624277      9.826590  12.716763    4.046243   9.248555
# SCD       16.666667     16.666667   0.000000    0.000000   0.000000
# SNES       3.765690     20.920502   4.184100    3.765690  20.502092
# TG16       0.000000      0.000000  50.000000    0.000000   0.000000
# WS         0.000000     66.666667   0.000000    0.000000   0.000000
# Wii        7.045455      2.651515   4.924242    6.590909  19.696970
# WiiU       2.040816      4.761905   6.802721    0.680272   5.442177
# X360       8.240887      5.942948  16.085578    3.169572  17.194929
# XB        14.927184      2.791262  16.019417    2.912621  20.631068
# XOne       8.097166      5.668016  15.384615    1.619433  15.384615
# All        7.471436      8.972902   7.914099    5.228211  14.045582
#
# Genre      Strategy    All
# Platform
# 2600       0.000000  100.0
# 3DO        0.000000  100.0
# 3DS        2.884615  100.0
# DC         0.000000  100.0
# DS         3.671004  100.0
# GB         7.142857  100.0
# GBA        2.189781  100.0
# GC         1.978417  100.0
# GEN        3.703704  100.0
# GG         0.000000  100.0
# N64        2.821317  100.0
# NES        0.000000  100.0
# NG         0.000000  100.0
# PC        19.301848  100.0
# PCFX       0.000000  100.0
# PS         5.931495  100.0
# PS2        3.285516  100.0
# PS3        1.803156  100.0
# PS4        1.526718  100.0
# PSP        4.962779  100.0
# PSV        1.620370  100.0
# SAT       10.404624  100.0
# SCD       16.666667  100.0
# SNES       6.276151  100.0
# TG16       0.000000  100.0
# WS        33.333333  100.0
# Wii        1.893939  100.0
# WiiU       2.040816  100.0
# X360       2.218700  100.0
# XB         2.548544  100.0
# XOne       1.214575  100.0
# All        4.085661  100.0

# %% [markdown]
# E se eu quiser uma tabela dessas, mas apenas contendo os jogos que venderam mais de 10 milhões de unidades?

# %%
pd.crosstab(vg[vg.Global_Sales>10].Platform,vg[vg.Global_Sales>10].Genre,margins = True).apply(lambda v:100*v/v[-1],axis = 1)
# Out:
# Genre        Action  Adventure   Fighting       Misc    Platform     Puzzle  \
# Platform
# 3DS        0.000000   0.000000   0.000000   0.000000   25.000000   0.000000
# DS        10.000000   0.000000   0.000000  10.000000   20.000000  10.000000
# GB         0.000000  16.666667   0.000000   0.000000   16.666667  16.666667
# GBA        0.000000   0.000000   0.000000   0.000000    0.000000   0.000000
# N64        0.000000   0.000000   0.000000   0.000000  100.000000   0.000000
# NES        0.000000   0.000000   0.000000   0.000000   66.666667   0.000000
# PS         0.000000   0.000000   0.000000   0.000000    0.000000   0.000000
# PS2       60.000000   0.000000   0.000000   0.000000    0.000000   0.000000
# PS3       28.571429   0.000000   0.000000   0.000000    0.000000   0.000000
# PS4       50.000000   0.000000   0.000000   0.000000    0.000000   0.000000
# SNES       0.000000   0.000000   0.000000   0.000000  100.000000   0.000000
# Wii        0.000000   0.000000  10.000000  20.000000   20.000000   0.000000
# X360      22.222222   0.000000   0.000000  11.111111    0.000000   0.000000
# All       14.516129   1.612903   1.612903   6.451613   17.741935   3.225806
#
# Genre         Racing  Role-Playing    Shooter  Simulation     Sports    All
# Platform
# 3DS        25.000000     50.000000   0.000000    0.000000   0.000000  100.0
# DS         10.000000     20.000000   0.000000   20.000000   0.000000  100.0
# GB          0.000000     50.000000   0.000000    0.000000   0.000000  100.0
# GBA         0.000000    100.000000   0.000000    0.000000   0.000000  100.0
# N64         0.000000      0.000000   0.000000    0.000000   0.000000  100.0
# NES         0.000000      0.000000  33.333333    0.000000   0.000000  100.0
# PS        100.000000      0.000000   0.000000    0.000000   0.000000  100.0
# PS2        40.000000      0.000000   0.000000    0.000000   0.000000  100.0
# PS3        14.285714      0.000000  57.142857    0.000000   0.000000  100.0
# PS4         0.000000      0.000000  50.000000    0.000000   0.000000  100.0
# SNES        0.000000      0.000000   0.000000    0.000000   0.000000  100.0
# Wii        10.000000      0.000000   0.000000    0.000000  40.000000  100.0
# X360        0.000000      0.000000  66.666667    0.000000   0.000000  100.0
# All        11.290323     14.516129  19.354839    3.225806   6.451613  100.0

# %% [markdown]
# ## Tabelas Pivo ##
#
# Muitas vezes, queremos cruzar dados de formas mais complexas. A tabela pivo ajuda muito nisso.
#
#
# Exemplo: Quem teve os melhores RPGs e adventures de acordo com a crítica? O primeiro ou o segundo Playstation?

# %%
rpgs = vg[(vg.Platform.isin(['PS2','PS']))& vg.Genre.isin(['Role-Playing','Adventure']) ]
rpgs.head()
pivot = rpgs.pivot_table(values=['Critic_Score'],index = ['Platform','Genre'],aggfunc = [np.mean,])
pivot
# Out:
#                               mean
#                       Critic_Score
# Platform Genre
# PS       Adventure       58.000000
#          Role-Playing    79.428571
# PS2      Adventure       62.348837
#          Role-Playing    71.639344

# %%
pivot.plot(kind='barh')

# %% [markdown]
# Exercício:
#
# Faça uma tabela contendo a media das notas de usuários dos jogos das Publishers Capcom e Activision de acordo com o Rating

# %%
rpgs = vg[(vg.Publisher.isin(['Activision','Capcom']))& (vg.Rating.notnull())]
rpgs.head()
pivot = rpgs.pivot_table(values=['User_Score'],index = ['Publisher','Rating'],aggfunc = [np.mean,])
pivot
# Out:
#                         mean
#                   User_Score
# Publisher  Rating
# Activision E        6.689109
#            E10+     6.490909
#            M        6.146667
#            T        7.055185
# Capcom     E        7.697500
#            E10+     8.125000
#            M        7.219277
#            T        7.349351

# %% [markdown]
# E se eu quiser saber quantas unidades o jogo mais vendido de cada plataforma vendeu?

# %%
vg.groupby(['Platform'])['Critic_Score'].mean().sort_values(ascending=False)
# Out:
# Platform
# DC      87.357143
# PC      75.928671
# XOne    73.325444
# PS4     72.091270
# PS      71.515000
# PSV     70.791667
# WiiU    70.733333
# PS3     70.382927
# XB      69.859310
# GC      69.488839
# PS2     68.727273
# X360    68.616812
# PSP     67.424242
# GBA     67.372146
# 3DS     67.101190
# DS      63.761506
# Wii     62.823932
# 2600          NaN
# 3DO           NaN
# GB            NaN
# GEN           NaN
# GG            NaN
# N64           NaN
# NES           NaN
# NG            NaN
# PCFX          NaN
# SAT           NaN
# SCD           NaN
# SNES          NaN
# TG16          NaN
# WS            NaN
# Name: Critic_Score, dtype: float64

# %%
vg.groupby(['Platform'])['Global_Sales'].sum().sort_values(ascending=False).plot(kind='bar')

# %% [markdown]
# ## Agrupando ##
#
# Você pode usar o comando groupby para gerar novas bases de dados modificadas. Por exemplo, você pode tentar prever as vendas totais de plataformas ao invés de jogos individuais. Contudo, para você utilizar os dados agrupados, você deve usar uma função de agregação (sum,count, min,max, mean, etc).
#
# ### Exemplo ###
#
# Criando um agrupamento por plataforma

# %%
vgplat = vg.groupby(['Platform'])
vgplat.Global_Sales.sum()
# Out:
# Platform
# 2600      97.08
# 3DO        0.10
# 3DS      259.09
# DC        15.97
# DS       807.10
# GB       255.45
# GBA      318.50
# GC       199.36
# GEN       30.78
# GG         0.04
# N64      218.88
# NES      251.07
# NG         1.44
# PC       260.30
# PCFX       0.03
# PS       730.68
# PS2     1255.64
# PS3      939.43
# PS4      314.23
# PSP      294.30
# PSV       54.12
# SAT       33.59
# SCD        1.87
# SNES     200.05
# TG16       0.16
# WS         1.42
# Wii      908.13
# WiiU      82.16
# X360     971.63
# XB       258.26
# XOne     159.44
# Name: Global_Sales, dtype: float64

# %% [markdown]
# Fazendo uma regressão para descobrir total de vendas de um console pelo total de jogos lançados para ele:

# %%
x = vgplat.Name.count()
y = vgplat.Global_Sales.sum()
plt.scatter(x,y)

# %%
#Total de anos que um console teve jogos

anos = vgplat.Year_of_Release.max() - vgplat.Year_of_Release.min()
anos.plot(kind='bar')

# %% [markdown]
# Vocês poderiam usar a informação de ano para ponderar alguma outra informação usada na regressão por exemplo. Contudo, tem algo estranho né? O Nintendo DS está com 35 anos de jogos lançados. Vocês conseguem descobrir o porquê?
